# %%
# Load the dataset into a pandas dataframe.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

cereal = pd.read_csv(r"cereal.csv")

# %%
# Print the first 5 rows of the dataset.
print(cereal.head())

# %%
# Use pandas to generate a description of the dataset.
cereal.describe()

# %%
cereal_corr = cereal[["calories", "protein", "fat", "sodium", "fiber", "carbo", "sugars", "potass", "vitamins", "shelf", "weight", "cups", "rating"]].corr()*100
print(cereal_corr)

high_corr = cereal_corr.unstack().sort_values(ascending=False).drop_duplicates().head(1)
print("\nColumn pair with highest correlation:", high_corr)




# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
cereal_corr = cereal[["calories", "protein", "fat", "sodium", "fiber", "carbo", "sugars", "potass", "vitamins", "shelf", "weight", "cups", "rating"]].corr()*100
print(cereal_corr)

high_corr = cereal_corr.unstack().sort_values(ascending=False).head(1)
lowest_corr = cereal_corr.unstack().sort_values().head(2)
print("\nColumn pair with highest correlation:", high_corr)
print("\nColumn pair with lowesr correlation:", lowest_corr)




# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
cereal_corr = cereal[["calories", "protein", "fat", "sodium", "fiber", "carbo", "sugars", "potass", "vitamins", "shelf", "weight", "cups", "rating"]].corr()*100
print(cereal_corr)

high_corr = cereal_corr.unstack().sort_values(ascending=False).head(1)
lowest_corr = cereal_corr.unstack().sort_values().head(1)
print("\nColumn pair with highest correlation:", high_corr)
print("\nColumn pair with lowesr correlation:", lowest_corr)




# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
cereal_corr = cereal[["calories", "protein", "fat", "sodium", "fiber", "carbo", "sugars", "potass", "vitamins", "shelf", "weight", "cups", "rating"]].corr()*100
print(cereal_corr)

high_corr = cereal_corr.unstack().sort_values().head(1)
lowest_corr = cereal_corr.unstack().sort_values().head(1)
print("\nColumn pair with highest correlation:", high_corr)
print("\nColumn pair with lowesr correlation:", lowest_corr)




# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
cereal_corr = cereal[["calories", "protein", "fat", "sodium", "fiber", "carbo", "sugars", "potass", "vitamins", "shelf", "weight", "cups", "rating"]].corr()*100
print(cereal_corr)

high_corr = cereal_corr.unstack().sort_values(ascending = False).head(1)
lowest_corr = cereal_corr.unstack().sort_values(ascending = True).head(1)
print("\nColumn pair with highest correlation:", high_corr)
print("\nColumn pair with lowesr correlation:", lowest_corr)




# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
fig, ax = plt.subplots()v
ax.hist(data.salary, bins = 100)
ax.set_xticks(np.linspace(0, 1500000, 4))
ax.set_xlim(0, 1500000)
ax.ticklabel_format(useOffset=False)
ax.ticklabel_format(style='plain')
ax.set_xlabel("Salary [$]")
ax.set_ylabel("Count")
ax.set_title("Amount of Earners")



# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
fig, ax = plt.subplots()
ax.hist(data.salary, bins = 100)
ax.set_xticks(np.linspace(0, 1500000, 4))
ax.set_xlim(0, 1500000)
ax.ticklabel_format(useOffset=False)
ax.ticklabel_format(style='plain')
ax.set_xlabel("Salary [$]")
ax.set_ylabel("Count")
ax.set_title("Amount of Earners")



# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
fig, ax = plt.subplots()
ax.set_facecolor("blue")
ax.hist(data.salary, bins = 100)
ax.set_xticks(np.linspace(0, 1500000, 4))
ax.set_xlim(0, 1500000)
ax.ticklabel_format(useOffset=False)
ax.ticklabel_format(style='plain')
ax.set_xlabel("Salary [$]")
ax.set_ylabel("Count")
ax.set_title("Amount of Earners")



# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
fig, ax = plt.subplots()
ax.set_facecolor("teal")
ax.hist(data.salary, bins = 100)
ax.set_xticks(np.linspace(0, 1500000, 4))
ax.set_xlim(0, 1500000)
ax.ticklabel_format(useOffset=False)
ax.ticklabel_format(style='plain')
ax.set_xlabel("Salary [$]")
ax.set_ylabel("Count")
ax.set_title("Amount of Earners")



# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
fig, ax = plt.subplots()
ax.set_facecolor("teal")

# ax.hist(data.salary, bins = 100)
ax.set_xticks(range(len(cereal_corr)))
ax.set_yticks(range(len(cereal_corr)))
ax.set_xlim(0, 1500000)
ax.ticklabel_format(useOffset=False)
ax.ticklabel_format(style='plain')
ax.set_xlabel("Salary [$]")
ax.set_ylabel("Count")
ax.set_title("Amount of Earners")



# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
fig, ax = plt.subplots()
ax.set_facecolor("teal")

ax.hist(data.salary, bins = 100)
ax.set_xticks(range(len(cereal_corr)))
ax.set_yticks(range(len(cereal_corr)))
ax.set_xlim(0, 1500000)
ax.ticklabel_format(useOffset=False)
ax.ticklabel_format(style='plain')
ax.set_xlabel("Salary [$]")
ax.set_ylabel("Count")
ax.set_title("Amount of Earners")



# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
fig, ax = plt.subplots()
ax.set_facecolor("teal")

ax.hist(cereal_corr, bins = 100)
ax.set_xticks(range(len(cereal_corr)))
ax.set_yticks(range(len(cereal_corr)))
ax.set_xlim(0, 1500000)
ax.ticklabel_format(useOffset=False)
ax.ticklabel_format(style='plain')
ax.set_xlabel("Salary [$]")
ax.set_ylabel("Count")
ax.set_title("Amount of Earners")



# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.

# %%
plt.matshow(cereal_corr)
plt.show()
# fig, ax = plt.subplots()
# ax.set_facecolor("teal")

# ax.hist(cereal_corr, bins = 100)
# ax.set_xticks(range(len(cereal_corr)))
# ax.set_yticks(range(len(cereal_corr)))
# ax.set_xlim(0, 1500000)
# ax.ticklabel_format(useOffset=False)
# ax.ticklabel_format(style='plain')
# ax.set_xlabel("Salary [$]")
# ax.set_ylabel("Count")
# ax.set_title("Amount of Earners")



# Make sure each plot is visually appealing, has a title, and has labeled axes. Make sure that the axis ticks make sense. Make each graph have a consistent theme and color scheme across all graphs.

# Load the dataset into a pandas dataframe.

# Print the first 5 rows of the dataset.

# Use pandas to generate a description of the dataset.

# Print the correlation matrix of the dataset. Which two columns have the highest correlation? Which two columns have the lowest correlation? Generate a correlation matrix plot using pandas.

# Use pandas to plot a scatter matrix of the dataset.

# Create a bar chart of the number of cereals in each manufacturer using the graphing library of your choice.

# Generate a scatter plot of the calories vs. the rating of the cereal using the graphing library of your choice.

# Select a few interesting looking graphs from the scatter matrix generated in problem 6 and make them visually appealing using the graphing library of your choice.

# Create a histogram of the ratings of the cereals using the graphing library of your choice.

# Describe any conclusions you can make about the dataset.
